# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Def modeling: regresiones, modelos ML

# %%
def modeling(data,models,version,iteracion):
    results_dict = {
    'Version_data': version,
    'Version_iteracion': iteracion,
    'State': [],
    'Modelo': [],
    'Parameters': [],
    'R2': [],
    'MAE': [],
    'RMSE': []
}
    states = data['State'].unique()

    for state in states:
        data_state = data[data['State'] == state]
        X = data_state.drop(['MedianPrice', 'State'], axis=1)
        y = data_state['MedianPrice'] 
        
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        for name, model, params in models:
            pipeline = Pipeline([
                ('scaler', StandardScaler()), 
                ('model', model)
            ])

            grid_search = GridSearchCV(pipeline, param_grid=params, cv=5, scoring='r2')
            grid_search.fit(X_scaled, y)

            y_pred = grid_search.predict(X_scaled)
            mae = mean_absolute_error(y, y_pred)
            rmse = mean_squared_error(y, y_pred, squared=False)

            results_dict['State'].append(state)
            results_dict['Modelo'].append(name)
            results_dict['Parameters'].append(grid_search.best_params_)
            results_dict['R2'].append(grid_search.best_score_)
            results_dict['MAE'].append(mae)
            results_dict['RMSE'].append(rmse)

    results_df = pd.DataFrame(results_dict)
    best_models_df = results_df.loc[results_df.groupby('State')['R2'].idxmax()]

    return best_models_df

# %%
models = [
    ('SVR', SVR(), {'model__C': [0.1, 1, 10], 'model__gamma': [0.1, 0.01, 0.001]}),
    ('KNeighborsRegressor', KNeighborsRegressor(), {'model__n_neighbors': [3, 5, 7],'model__weights': ['uniform', 'distance']}),
    ('Lasso', Lasso(), {'model__alpha': [0.1, 0.5, 1.0]}),
    ('LinearRegression', LinearRegression(), {}),
    ('KNN', KNeighborsRegressor(), {'model__n_neighbors': [3, 5, 7]}),
    ('RandomForest', RandomForestRegressor(), {'model__n_estimators': [50, 100, 150]}),
    ('GradientBoosting', GradientBoostingRegressor(), {'model__n_estimators': [50, 100, 150]}),
    ('AdaBoost', AdaBoostRegressor(), {'model__n_estimators': [50, 100, 150]}),
    ('XGBoost', XGBRegressor(), {'model__n_estimators': [50, 100, 150]})
]

# %% [markdown]
# # 1. Models all pca

# %%
data_pca = pd.read_csv('../data/process_data/all_pca.csv')

# %%
models_pca = modeling(data = data_pca,models = models,version = 'all_pca', iteracion='iter1-normal')
models_pca
# Out:
#    Version_data Version_iteracion State            Modelo  \
# 5       all_pca      iter1-normal    FL      RandomForest
# 59      all_pca      iter1-normal    GA      RandomForest
# 32      all_pca      iter1-normal    NC      RandomForest
# 12      all_pca      iter1-normal    NJ  LinearRegression
# 24      all_pca      iter1-normal    NY  GradientBoosting
# 44      all_pca      iter1-normal    SC           XGBoost
# 50      all_pca      iter1-normal    VA      RandomForest
#
#                       Parameters        R2           MAE          RMSE
# 5    {'model__n_estimators': 50}  0.375347  15149.451613  24454.906091
# 59  {'model__n_estimators': 100}  0.780612   6906.866242   9479.686978
# 32  {'model__n_estimators': 150}  0.579183  10092.545455  13717.572463
# 12                            {}  0.595462  31778.200052  35635.501147
# 24   {'model__n_estimators': 50}  0.800524   5695.664416   7399.592826
# 44  {'model__n_estimators': 100}  0.701486      0.017188      0.024122
# 50   {'model__n_estimators': 50}  0.841174   9015.595506  14142.744028

# %% [markdown]
# # 2. Models all log

# %%
data_log = pd.read_csv('../data/process_data/all_log.csv')

# %%
models_log = modeling(data = data_log,models = models,version = 'all_log',iteracion='iter1-normal')
models_log
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.551e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.293e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.013e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.671e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.084e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.548e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.260e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.996e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.635e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.056e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.544e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.218e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.975e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.588e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.021e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.342e+09, tolerance: 4.374e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.825e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.161e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.080e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.110e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.463e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.818e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.163e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.063e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.401e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.810e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.164e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.041e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.096e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.324e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.257e+09, tolerance: 5.810e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.873e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.383e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.413e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.351e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.315e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.807e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.331e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.373e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.294e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.262e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.726e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.264e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.324e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.221e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.195e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.519e+09, tolerance: 3.127e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.118e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.156e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.097e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.233e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.654e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.111e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.043e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.076e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.171e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.622e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.102e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.913e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.052e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.095e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.585e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.559e+09, tolerance: 1.544e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.344e+10, tolerance: 8.026e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.594e+10, tolerance: 7.942e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.774e+10, tolerance: 9.612e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.347e+10, tolerance: 1.111e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.134e+10, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.325e+10, tolerance: 8.026e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.587e+10, tolerance: 7.942e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.770e+10, tolerance: 9.612e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.331e+10, tolerance: 1.111e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.117e+10, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.302e+10, tolerance: 8.026e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.577e+10, tolerance: 7.942e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.765e+10, tolerance: 9.612e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.312e+10, tolerance: 1.111e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.095e+10, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.855e+10, tolerance: 1.182e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.780e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.491e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.840e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.583e+10, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.594e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.773e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.485e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.830e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.576e+10, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.582e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.765e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.477e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.818e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.568e+10, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.567e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.193e+10, tolerance: 5.489e+07
#   model = cd_fast.enet_coordinate_descent(
#    Version_data Version_iteracion State            Modelo  \
# 6       all_log      iter1-normal    FL  GradientBoosting
# 57      all_log      iter1-normal    GA  LinearRegression
# 30      all_log      iter1-normal    NC  LinearRegression
# 16      all_log      iter1-normal    NJ          AdaBoost
# 24      all_log      iter1-normal    NY  GradientBoosting
# 41      all_log      iter1-normal    SC      RandomForest
# 51      all_log      iter1-normal    VA  GradientBoosting
#
#                       Parameters        R2           MAE          RMSE
# 6   {'model__n_estimators': 150}  0.796257    125.193771    159.814824
# 57                            {}  0.825087  13157.467104  16222.984727
# 30                            {}  0.868397  10242.503225  13541.985270
# 16  {'model__n_estimators': 100}  0.534020   4898.027778   6671.579904
# 24  {'model__n_estimators': 150}  0.885118    181.423916    227.745020
# 41   {'model__n_estimators': 50}  0.805469   6818.400000  10484.321925
# 51   {'model__n_estimators': 50}  0.866787   4293.007636   5515.274653

# %% [markdown]
# # 3. Models new values

# %%
data_new_values = pd.read_csv('../data/process_data/new_values.csv')

# %%
models_new_values = modeling(data = data_new_values,models = models,version = 'new_values',iteracion='iter1-normal')
models_new_values
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.503e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.321e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.825e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.187e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.553e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.141e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.256e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.097e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.280e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.708e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.866e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.597e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.987e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.952e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.033e+10, tolerance: 4.374e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.507e+08, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.854e+08, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.170e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.523e+08, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.858e+08, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.727e+07, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.183e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.541e+08, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.863e+08, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.485e+07, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.198e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.552e+09, tolerance: 1.858e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.156e+10, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.926e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.026e+10, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.489e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.238e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+10, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.793e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.398e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.268e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.507e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.094e+10, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.630e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.460e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.971e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.756e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.197e+10, tolerance: 5.810e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.052e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.003e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.728e+08, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.784e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.627e+08, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.724e+08, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.594e+08, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.781e+08, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.100e+08, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.520e+08, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.004e+08, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.406e+08, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.831e+08, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.420e+08, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.528e+08, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.017e+08, tolerance: 3.127e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.285e+07, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.561e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.056e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.231e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.837e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.478e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.366e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.723e+08, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.797e+07, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.034e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.699e+07, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.197e+07, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.738e+08, tolerance: 1.544e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.626e+08, tolerance: 8.121e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.393e+08, tolerance: 7.891e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.933e+08, tolerance: 9.656e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.259e+08, tolerance: 1.110e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.823e+09, tolerance: 1.048e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.875e+08, tolerance: 8.121e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.389e+08, tolerance: 7.891e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.949e+08, tolerance: 9.656e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.281e+08, tolerance: 1.048e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.491e+08, tolerance: 8.121e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.412e+08, tolerance: 7.891e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+08, tolerance: 9.656e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.677e+08, tolerance: 1.048e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.479e+09, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.386e+08, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.489e+08, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.338e+09, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.879e+08, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.487e+09, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.791e+08, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.464e+08, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.320e+09, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.582e+08, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.097e+08, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.743e+08, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.490e+08, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.324e+09, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.571e+08, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.761e+08, tolerance: 5.489e+07
#   model = cd_fast.enet_coordinate_descent(
#    Version_data Version_iteracion State               Modelo  \
# 6    new_values      iter1-normal    FL     GradientBoosting
# 56   new_values      iter1-normal    GA                Lasso
# 30   new_values      iter1-normal    NC     LinearRegression
# 10   new_values      iter1-normal    NJ  KNeighborsRegressor
# 24   new_values      iter1-normal    NY     GradientBoosting
# 38   new_values      iter1-normal    SC                Lasso
# 52   new_values      iter1-normal    VA             AdaBoost
#
#                                            Parameters        R2           MAE  \
# 6                        {'model__n_estimators': 150}  0.797930    126.939480
# 56                              {'model__alpha': 1.0}  0.878805  12267.590107
# 30                                                 {}  0.911957  10052.628324
# 10  {'model__n_neighbors': 3, 'model__weights': 'u...  0.452062  31431.666667
# 24                       {'model__n_estimators': 100}  0.899687    370.935292
# 38                              {'model__alpha': 1.0}  0.835408   8479.319918
# 52                       {'model__n_estimators': 150}  0.887729  14866.883071
#
#             RMSE
# 6     149.012802
# 56  15930.705726
# 30  12590.826233
# 10  37522.367403
# 24    443.085844
# 38  10491.318644
# 52  17302.998528

# %% [markdown]
# # 4. Models new values log

# %%
data_new_values_log = pd.read_csv('../data/process_data/new_values_log.csv')

# %%
models_new_values_log = modeling(data = data_new_values_log,models = models,version = 'new_values_log',
iteracion='iter1-normal')
models_new_values_log
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.077e+09, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.399e+08, tolerance: 1.393e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.221e+09, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.033e+09, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.925e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.049e+09, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.404e+08, tolerance: 1.393e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.980e+09, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.006e+09, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.920e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.013e+09, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.409e+08, tolerance: 1.393e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.690e+09, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.972e+09, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.913e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.547e+09, tolerance: 1.858e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.735e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.221e+08, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.119e+07, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.224e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.049e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.123e+07, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.747e+08, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.446e+07, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.284e+08, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.230e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.632e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.149e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.348e+09, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.424e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.018e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.219e+09, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.626e+09, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.143e+08, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.838e+09, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.098e+09, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.163e+09, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.790e+09, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.373e+08, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.484e+09, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.973e+09, tolerance: 5.489e+07
#   model = cd_fast.enet_coordinate_descent(
#       Version_data Version_iteracion State            Modelo  \
# 6   new_values_log      iter1-normal    FL  GradientBoosting
# 56  new_values_log      iter1-normal    GA             Lasso
# 29  new_values_log      iter1-normal    NC             Lasso
# 16  new_values_log      iter1-normal    NJ          AdaBoost
# 24  new_values_log      iter1-normal    NY  GradientBoosting
# 41  new_values_log      iter1-normal    SC      RandomForest
# 50  new_values_log      iter1-normal    VA      RandomForest
#
#                       Parameters        R2           MAE          RMSE
# 6   {'model__n_estimators': 150}  0.792581    231.957811    281.239279
# 56         {'model__alpha': 1.0}  0.810443  16130.218802  20637.769007
# 29         {'model__alpha': 1.0}  0.843991  14464.243178  18002.906382
# 16   {'model__n_estimators': 50}  0.380502   4658.988095   7524.143128
# 24  {'model__n_estimators': 150}  0.899639    171.698639    221.469462
# 41  {'model__n_estimators': 100}  0.803412   6399.400000   9715.786308
# 50  {'model__n_estimators': 150}  0.775796  10474.613636  15769.429278

# %% [markdown]
# # 5. Get results

# %%
frames = [models_pca, models_log, models_new_values, models_new_values_log]
models_result = pd.concat(frames)

models_result = models_result.reset_index(drop=True).sort_values(by=['State','R2'], ascending = [True,False])

models_result
# Out:
#       Version_data Version_iteracion State               Modelo  \
# 14      new_values      iter1-normal    FL     GradientBoosting
# 7          all_log      iter1-normal    FL     GradientBoosting
# 21  new_values_log      iter1-normal    FL     GradientBoosting
# 0          all_pca      iter1-normal    FL         RandomForest
# 15      new_values      iter1-normal    GA                Lasso
# 8          all_log      iter1-normal    GA     LinearRegression
# 22  new_values_log      iter1-normal    GA                Lasso
# 1          all_pca      iter1-normal    GA         RandomForest
# 16      new_values      iter1-normal    NC     LinearRegression
# 9          all_log      iter1-normal    NC     LinearRegression
# 23  new_values_log      iter1-normal    NC                Lasso
# 2          all_pca      iter1-normal    NC         RandomForest
# 3          all_pca      iter1-normal    NJ     LinearRegression
# 10         all_log      iter1-normal    NJ             AdaBoost
# 17      new_values      iter1-normal    NJ  KNeighborsRegressor
# 24  new_values_log      iter1-normal    NJ             AdaBoost
# 18      new_values      iter1-normal    NY     GradientBoosting
# 25  new_values_log      iter1-normal    NY     GradientBoosting
# 11         all_log      iter1-normal    NY     GradientBoosting
# 4          all_pca      iter1-normal    NY     GradientBoosting
# 19      new_values      iter1-normal    SC                Lasso
# 12         all_log      iter1-normal    SC         RandomForest
# 26  new_values_log      iter1-normal    SC         RandomForest
# 5          all_pca      iter1-normal    SC              XGBoost
# 20      new_values      iter1-normal    VA             AdaBoost
# 13         all_log      iter1-normal    VA     GradientBoosting
# 6          all_pca      iter1-normal    VA         RandomForest
# 27  new_values_log      iter1-normal    VA         RandomForest
#
#                                            Parameters        R2           MAE  \
# 14                       {'model__n_estimators': 150}  0.797930    126.939480
# 7                        {'model__n_estimators': 150}  0.796257    125.193771
# 21                       {'model__n_estimators': 150}  0.792581    231.957811
# 0                         {'model__n_estimators': 50}  0.375347  15149.451613
# 15                              {'model__alpha': 1.0}  0.878805  12267.590107
# 8                                                  {}  0.825087  13157.467104
# 22                              {'model__alpha': 1.0}  0.810443  16130.218802
# 1                        {'model__n_estimators': 100}  0.780612   6906.866242
# 16                                                 {}  0.911957  10052.628324
# 9                                                  {}  0.868397  10242.503225
# 23                              {'model__alpha': 1.0}  0.843991  14464.243178
# 2                        {'model__n_estimators': 150}  0.579183  10092.545455
# 3                                                  {}  0.595462  31778.200052
# 10                       {'model__n_estimators': 100}  0.534020   4898.027778
# 17  {'model__n_neighbors': 3, 'model__weights': 'u...  0.452062  31431.666667
# 24                        {'model__n_estimators': 50}  0.380502   4658.988095
# 18                       {'model__n_estimators': 100}  0.899687    370.935292
# 25                       {'model__n_estimators': 150}  0.899639    171.698639
# 11                       {'model__n_estimators': 150}  0.885118    181.423916
# 4                         {'model__n_estimators': 50}  0.800524   5695.664416
# 19                              {'model__alpha': 1.0}  0.835408   8479.319918
# 12                        {'model__n_estimators': 50}  0.805469   6818.400000
# 26                       {'model__n_estimators': 100}  0.803412   6399.400000
# 5                        {'model__n_estimators': 100}  0.701486      0.017188
# 20                       {'model__n_estimators': 150}  0.887729  14866.883071
# 13                        {'model__n_estimators': 50}  0.866787   4293.007636
# 6                         {'model__n_estimators': 50}  0.841174   9015.595506
# 27                       {'model__n_estimators': 150}  0.775796  10474.613636
#
#             RMSE
# 14    149.012802
# 7     159.814824
# 21    281.239279
# 0   24454.906091
# 15  15930.705726
# 8   16222.984727
# 22  20637.769007
# 1    9479.686978
# 16  12590.826233
# 9   13541.985270
# 23  18002.906382
# 2   13717.572463
# 3   35635.501147
# 10   6671.579904
# 17  37522.367403
# 24   7524.143128
# 18    443.085844
# 25    221.469462
# 11    227.745020
# 4    7399.592826
# 19  10491.318644
# 12  10484.321925
# 26   9715.786308
# 5       0.024122
# 20  17302.998528
# 13   5515.274653
# 6   14142.744028
# 27  15769.429278

# %%
models_result.to_excel('../data/final_data/models_results.xlsx', index = False)
