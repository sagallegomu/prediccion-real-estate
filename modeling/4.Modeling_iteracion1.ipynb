# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Def modeling: regresiones, modelos ML

# %%
def modeling(data,models,version,iteracion):
    results_dict = {
    'Version_data': version,
    'Version_iteracion': iteracion,
    'State': [],
    'Modelo': [],
    'Parameters': [],
    'R2': [],
    'MAE': [],
    'RMSE': []
}
    states = data['State'].unique()

    for state in states:
        data_state = data[data['State'] == state]
        X = data_state.drop(['MedianPrice', 'State'], axis=1)
        y = data_state['MedianPrice'] 
        
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        for name, model, params in models:
            pipeline = Pipeline([
                ('scaler', StandardScaler()), 
                ('model', model)
            ])

            grid_search = GridSearchCV(pipeline, param_grid=params, cv=5, scoring='r2')
            grid_search.fit(X_scaled, y)

            y_pred = grid_search.predict(X_scaled)
            mae = mean_absolute_error(y, y_pred)
            rmse = mean_squared_error(y, y_pred, squared=False)

            results_dict['State'].append(state)
            results_dict['Modelo'].append(name)
            results_dict['Parameters'].append(grid_search.best_params_)
            results_dict['R2'].append(grid_search.best_score_)
            results_dict['MAE'].append(mae)
            results_dict['RMSE'].append(rmse)

    results_df = pd.DataFrame(results_dict)
    best_models_df = results_df.loc[results_df.groupby('State')['R2'].idxmax()]

    return best_models_df

# %%
models = [
    ('SVR', SVR(), {'model__C': [0.1, 1, 10], 'model__gamma': [0.1, 0.01, 0.001]}),
    ('KNeighborsRegressor', KNeighborsRegressor(), {'model__n_neighbors': [3, 5, 7],'model__weights': ['uniform', 'distance']}),
    ('Lasso', Lasso(), {'model__alpha': [0.1, 0.5, 1.0]}),
    ('LinearRegression', LinearRegression(), {}),
    ('KNN', KNeighborsRegressor(), {'model__n_neighbors': [3, 5, 7]}),
    ('RandomForest', RandomForestRegressor(), {'model__n_estimators': [50, 100, 150]}),
    ('GradientBoosting', GradientBoostingRegressor(), {'model__n_estimators': [50, 100, 150]}),
    ('AdaBoost', AdaBoostRegressor(), {'model__n_estimators': [50, 100, 150]}),
    ('XGBoost', XGBRegressor(), {'model__n_estimators': [50, 100, 150]})
]

# %% [markdown]
# # 1. Models all pca

# %%
data_pca = pd.read_csv('../data/process_data/all_pca.csv')

# %%
models_pca = modeling(data = data_pca,models = models,version = 'all_pca', iteracion='iter1-normal')
models_pca
# Out:
#    Version_data Version_iteracion State            Modelo  \
# 5       all_pca      iter1-normal    FL      RandomForest
# 59      all_pca      iter1-normal    GA      RandomForest
# 32      all_pca      iter1-normal    NC      RandomForest
# 12      all_pca      iter1-normal    NJ  LinearRegression
# 24      all_pca      iter1-normal    NY  GradientBoosting
# 44      all_pca      iter1-normal    SC           XGBoost
# 50      all_pca      iter1-normal    VA      RandomForest
#
#                       Parameters        R2           MAE          RMSE
# 5   {'model__n_estimators': 150}  0.402307  14906.688172  22780.574768
# 59   {'model__n_estimators': 50}  0.781493   6901.503185   9199.355751
# 32  {'model__n_estimators': 100}  0.588117  10209.858586  13807.430095
# 12                            {}  0.595462  31778.200052  35635.501147
# 24   {'model__n_estimators': 50}  0.801728   5695.664416   7399.592826
# 44  {'model__n_estimators': 100}  0.701486      0.017188      0.024122
# 50   {'model__n_estimators': 50}  0.843262   9677.146067  14954.267899

# %% [markdown]
# # 2. Models all log

# %%
data_log = pd.read_csv('../data/process_data/all_log.csv')

# %%
models_log = modeling(data = data_log,models = models,version = 'all_log',iteracion='iter1-normal')
models_log
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.551e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.293e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.013e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.671e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.084e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.548e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.260e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.996e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.635e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.056e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.544e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.218e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.975e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.588e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.021e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.342e+09, tolerance: 4.374e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.825e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.161e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.080e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.110e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.463e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.818e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.163e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.063e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.401e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.810e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.164e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.041e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.096e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.324e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.257e+09, tolerance: 5.810e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.873e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.383e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.413e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.351e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.315e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.807e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.331e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.373e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.294e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.262e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.726e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.264e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.324e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.221e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.195e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.519e+09, tolerance: 3.127e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.118e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.156e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.097e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.233e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.654e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.111e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.043e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.076e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.171e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.622e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.102e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.913e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.052e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.095e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.585e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.559e+09, tolerance: 1.544e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.344e+10, tolerance: 8.026e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.594e+10, tolerance: 7.942e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.774e+10, tolerance: 9.612e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.347e+10, tolerance: 1.111e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.134e+10, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.325e+10, tolerance: 8.026e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.587e+10, tolerance: 7.942e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.770e+10, tolerance: 9.612e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.331e+10, tolerance: 1.111e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.117e+10, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.302e+10, tolerance: 8.026e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.577e+10, tolerance: 7.942e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.765e+10, tolerance: 9.612e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.312e+10, tolerance: 1.111e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.095e+10, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.855e+10, tolerance: 1.182e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.780e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.491e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.840e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.583e+10, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.594e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.773e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.485e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.830e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.576e+10, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.582e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.765e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.477e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.818e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.568e+10, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.567e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.193e+10, tolerance: 5.489e+07
#   model = cd_fast.enet_coordinate_descent(
#    Version_data Version_iteracion State            Modelo  \
# 6       all_log      iter1-normal    FL  GradientBoosting
# 57      all_log      iter1-normal    GA  LinearRegression
# 30      all_log      iter1-normal    NC  LinearRegression
# 16      all_log      iter1-normal    NJ          AdaBoost
# 24      all_log      iter1-normal    NY  GradientBoosting
# 41      all_log      iter1-normal    SC      RandomForest
# 51      all_log      iter1-normal    VA  GradientBoosting
#
#                       Parameters        R2           MAE          RMSE
# 6   {'model__n_estimators': 150}  0.781811    125.193771    159.814824
# 57                            {}  0.825087  13157.467104  16222.984727
# 30                            {}  0.868397  10242.503225  13541.985270
# 16  {'model__n_estimators': 150}  0.576942   4269.217949   6320.105363
# 24   {'model__n_estimators': 50}  0.884365   2432.939133   3007.131967
# 41  {'model__n_estimators': 150}  0.811089   6352.029630  10452.443832
# 51   {'model__n_estimators': 50}  0.868932   4293.007636   5515.274653

# %% [markdown]
# # 3. Models new values

# %%
data_new_values = pd.read_csv('../data/process_data/new_values.csv')

# %%
models_new_values = modeling(data = data_new_values,models = models,version = 'new_values',iteracion='iter1-normal')
models_new_values
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.051e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.978e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.093e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.935e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.480e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.669e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.689e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.720e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.864e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.251e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.196e+09, tolerance: 3.663e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.345e+09, tolerance: 3.772e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.270e+09, tolerance: 3.802e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.776e+09, tolerance: 2.191e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.974e+09, tolerance: 3.813e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.174e+09, tolerance: 4.374e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.861e+07, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.495e+07, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.586e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.980e+07, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.805e+07, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.589e+07, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.614e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.117e+07, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.179e+07, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.228e+07, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.647e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.558e+08, tolerance: 1.858e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.497e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.370e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.381e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.170e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.775e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.392e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.054e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.872e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.943e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.262e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.676e+09, tolerance: 5.464e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.285e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.692e+09, tolerance: 4.412e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.271e+09, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.043e+10, tolerance: 5.810e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.476e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.029e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.757e+09, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.790e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.672e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.732e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.443e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.194e+08, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.905e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.009e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.455e+09, tolerance: 2.461e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.119e+09, tolerance: 2.512e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.322e+08, tolerance: 2.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.333e+09, tolerance: 2.474e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.683e+09, tolerance: 2.416e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.159e+09, tolerance: 3.127e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.152e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.569e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.473e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.584e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.183e+09, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.785e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.372e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.342e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.108e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.081e+09, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.542e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.798e+08, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.180e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.165e+08, tolerance: 1.356e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.547e+08, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.448e+08, tolerance: 1.544e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.118e+10, tolerance: 8.121e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.432e+09, tolerance: 7.891e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.420e+09, tolerance: 9.656e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.713e+09, tolerance: 1.110e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.083e+10, tolerance: 1.048e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.041e+10, tolerance: 8.121e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.465e+09, tolerance: 7.891e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.969e+09, tolerance: 9.656e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.245e+09, tolerance: 1.110e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.046e+10, tolerance: 1.048e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.538e+09, tolerance: 8.121e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.921e+09, tolerance: 7.891e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.456e+09, tolerance: 9.656e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.702e+09, tolerance: 1.110e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.003e+10, tolerance: 1.048e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.098e+10, tolerance: 1.184e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.971e+07, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.022e+08, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.166e+08, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e+08, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.042e+08, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.115e+08, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.632e+08, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.149e+08, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+08, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.837e+07, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e+08, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.611e+08, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e+08, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.212e+08, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.439e+08, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.473e+08, tolerance: 5.489e+07
#   model = cd_fast.enet_coordinate_descent(
#    Version_data Version_iteracion State            Modelo  \
# 6    new_values      iter1-normal    FL  GradientBoosting
# 56   new_values      iter1-normal    GA             Lasso
# 30   new_values      iter1-normal    NC  LinearRegression
# 16   new_values      iter1-normal    NJ          AdaBoost
# 24   new_values      iter1-normal    NY  GradientBoosting
# 38   new_values      iter1-normal    SC             Lasso
# 52   new_values      iter1-normal    VA          AdaBoost
#
#                       Parameters        R2           MAE          RMSE
# 6   {'model__n_estimators': 150}  0.779057    168.839807    220.776706
# 56         {'model__alpha': 1.0}  0.878223  12165.527847  15611.276165
# 30                            {}  0.861908  11048.683667  14440.910867
# 16   {'model__n_estimators': 50}  0.511197   5057.678571   7364.584352
# 24  {'model__n_estimators': 150}  0.896580    130.374807    163.837320
# 38         {'model__alpha': 1.0}  0.858107   7297.583055   9056.313126
# 52  {'model__n_estimators': 100}  0.864547  13328.582656  15573.857944

# %% [markdown]
# # 4. Models new values log

# %%
data_new_values_log = pd.read_csv('../data/process_data/new_values_log.csv')

# %%
models_new_values_log = modeling(data = data_new_values_log,models = models,version = 'new_values_log',
iteracion='iter1-normal')
models_new_values_log
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.106e+07, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.423e+07, tolerance: 1.393e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.637e+07, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.649e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.637e+07, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.014e+07, tolerance: 1.393e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.997e+07, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.665e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.289e+07, tolerance: 1.301e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.729e+07, tolerance: 1.393e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.433e+07, tolerance: 1.600e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.149e+07, tolerance: 1.454e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.684e+08, tolerance: 1.637e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.932e+08, tolerance: 1.858e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.584e+09, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.887e+09, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.167e+08, tolerance: 5.219e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.498e+08, tolerance: 4.312e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.491e+09, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.582e+07, tolerance: 9.674e+06
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.429e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.419e+07, tolerance: 1.423e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.718e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.056e+09, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.983e+08, tolerance: 1.039e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.196e+08, tolerance: 1.379e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+08, tolerance: 1.045e+08
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.147e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.541e+10, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.960e+10, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.486e+08, tolerance: 4.673e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.339e+10, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.039e+10, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.811e+09, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.656e+09, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.612e+09, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.425e+09, tolerance: 4.425e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.609e+09, tolerance: 3.514e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.265e+09, tolerance: 4.707e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.396e+09, tolerance: 4.546e+07
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.287e+09, tolerance: 5.489e+07
#   model = cd_fast.enet_coordinate_descent(
#       Version_data Version_iteracion State            Modelo  \
# 5   new_values_log      iter1-normal    FL      RandomForest
# 59  new_values_log      iter1-normal    GA      RandomForest
# 29  new_values_log      iter1-normal    NC             Lasso
# 16  new_values_log      iter1-normal    NJ          AdaBoost
# 24  new_values_log      iter1-normal    NY  GradientBoosting
# 41  new_values_log      iter1-normal    SC      RandomForest
# 51  new_values_log      iter1-normal    VA  GradientBoosting
#
#                       Parameters        R2           MAE          RMSE
# 5    {'model__n_estimators': 50}  0.774959   8436.806452  17191.242285
# 59  {'model__n_estimators': 150}  0.816276   6063.605096   8093.136806
# 29         {'model__alpha': 1.0}  0.847543  12747.336619  16393.351508
# 16  {'model__n_estimators': 100}  0.510045   4656.982143   6669.691264
# 24  {'model__n_estimators': 100}  0.893538    678.748875    848.142881
# 41   {'model__n_estimators': 50}  0.808274   6157.955556   9534.816043
# 51  {'model__n_estimators': 150}  0.869694    655.799287    814.995361

# %% [markdown]
# # 5. Get results

# %%
frames = [models_pca, models_log, models_new_values, models_new_values_log]
models_result = pd.concat(frames)

models_result = models_result.reset_index(drop=True).sort_values(by=['State','R2'], ascending = [True,False])

models_result
# Out:
#       Version_data Version_iteracion State            Modelo  \
# 7          all_log      iter1-normal    FL  GradientBoosting
# 14      new_values      iter1-normal    FL  GradientBoosting
# 21  new_values_log      iter1-normal    FL      RandomForest
# 0          all_pca      iter1-normal    FL      RandomForest
# 15      new_values      iter1-normal    GA             Lasso
# 8          all_log      iter1-normal    GA  LinearRegression
# 22  new_values_log      iter1-normal    GA      RandomForest
# 1          all_pca      iter1-normal    GA      RandomForest
# 9          all_log      iter1-normal    NC  LinearRegression
# 16      new_values      iter1-normal    NC  LinearRegression
# 23  new_values_log      iter1-normal    NC             Lasso
# 2          all_pca      iter1-normal    NC      RandomForest
# 3          all_pca      iter1-normal    NJ  LinearRegression
# 10         all_log      iter1-normal    NJ          AdaBoost
# 17      new_values      iter1-normal    NJ          AdaBoost
# 24  new_values_log      iter1-normal    NJ          AdaBoost
# 18      new_values      iter1-normal    NY  GradientBoosting
# 25  new_values_log      iter1-normal    NY  GradientBoosting
# 11         all_log      iter1-normal    NY  GradientBoosting
# 4          all_pca      iter1-normal    NY  GradientBoosting
# 19      new_values      iter1-normal    SC             Lasso
# 12         all_log      iter1-normal    SC      RandomForest
# 26  new_values_log      iter1-normal    SC      RandomForest
# 5          all_pca      iter1-normal    SC           XGBoost
# 27  new_values_log      iter1-normal    VA  GradientBoosting
# 13         all_log      iter1-normal    VA  GradientBoosting
# 20      new_values      iter1-normal    VA          AdaBoost
# 6          all_pca      iter1-normal    VA      RandomForest
#
#                       Parameters        R2           MAE          RMSE
# 7   {'model__n_estimators': 150}  0.781811    125.193771    159.814824
# 14  {'model__n_estimators': 150}  0.779057    168.839807    220.776706
# 21   {'model__n_estimators': 50}  0.774959   8436.806452  17191.242285
# 0   {'model__n_estimators': 150}  0.402307  14906.688172  22780.574768
# 15         {'model__alpha': 1.0}  0.878223  12165.527847  15611.276165
# 8                             {}  0.825087  13157.467104  16222.984727
# 22  {'model__n_estimators': 150}  0.816276   6063.605096   8093.136806
# 1    {'model__n_estimators': 50}  0.781493   6901.503185   9199.355751
# 9                             {}  0.868397  10242.503225  13541.985270
# 16                            {}  0.861908  11048.683667  14440.910867
# 23         {'model__alpha': 1.0}  0.847543  12747.336619  16393.351508
# 2   {'model__n_estimators': 100}  0.588117  10209.858586  13807.430095
# 3                             {}  0.595462  31778.200052  35635.501147
# 10  {'model__n_estimators': 150}  0.576942   4269.217949   6320.105363
# 17   {'model__n_estimators': 50}  0.511197   5057.678571   7364.584352
# 24  {'model__n_estimators': 100}  0.510045   4656.982143   6669.691264
# 18  {'model__n_estimators': 150}  0.896580    130.374807    163.837320
# 25  {'model__n_estimators': 100}  0.893538    678.748875    848.142881
# 11   {'model__n_estimators': 50}  0.884365   2432.939133   3007.131967
# 4    {'model__n_estimators': 50}  0.801728   5695.664416   7399.592826
# 19         {'model__alpha': 1.0}  0.858107   7297.583055   9056.313126
# 12  {'model__n_estimators': 150}  0.811089   6352.029630  10452.443832
# 26   {'model__n_estimators': 50}  0.808274   6157.955556   9534.816043
# 5   {'model__n_estimators': 100}  0.701486      0.017188      0.024122
# 27  {'model__n_estimators': 150}  0.869694    655.799287    814.995361
# 13   {'model__n_estimators': 50}  0.868932   4293.007636   5515.274653
# 20  {'model__n_estimators': 100}  0.864547  13328.582656  15573.857944
# 6    {'model__n_estimators': 50}  0.843262   9677.146067  14954.267899

# %%
models_result.to_excel('../data/final_data/models_results.xlsx', index = False)
